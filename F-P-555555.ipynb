# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# Load the ECG dataset
data = pd.read_csv("http://storage.googleapis.com/download.tensorflow.org/data/ecg.csv",header=None)
data.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
#
#         7         8         9    ...       131       132       133       134  \
# 0 -1.818286 -1.250522 -0.477492  ...  0.792168  0.933541  0.796958  0.578621
# 1 -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490  0.724046
# 2 -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377 -0.021919
# 3 -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345  0.842069
# 4 -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025  1.371682
#
#         135       136       137       138       139  140
# 0  0.257740  0.228077  0.123431  0.925286  0.193137  1.0
# 1  0.555784  0.476333  0.773820  1.119621 -1.436250  1.0
# 2 -0.713683 -0.532197  0.321097  0.904227 -0.421797  1.0
# 3  0.952074  0.990133  1.086798  1.403011 -0.383564  1.0
# 4  1.277392  0.960304  0.971020  1.614392  1.421456  1.0
#
# [5 rows x 141 columns]

# %%
# Preprocess the data
scaler = StandardScaler()
X = scaler.fit_transform(data.values)
y = X  # Autoencoder input and output are the same

X_train, X_test, _, _ = train_test_split(X, X, test_size=0.2, random_state=42)

# %%
# Build and train the Autoencoder model
input_dim = X_train.shape[1]

# %%
encoder = keras.Sequential([
    keras.layers.Input(shape=(input_dim,)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(8, activation='relu')
])

# %%
decoder = keras.Sequential([
    keras.layers.Input(shape=(8,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(input_dim, activation='linear')  # Use linear activation for reconstruction
])

# %%
autoencoder = keras.models.Sequential([
    encoder,
    decoder
])


autoencoder.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
autoencoder.fit(X_train, X_train,validation_data=(X_test,X_test), epochs=100, batch_size=32, shuffle=True)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 1s 3ms/step - loss: 0.1066 - mse: 0.1066 - val_loss: 0.1155 - val_mse: 0.1155
# Epoch 2/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1058 - mse: 0.1058 - val_loss: 0.1136 - val_mse: 0.1136
# Epoch 3/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1059 - mse: 0.1059 - val_loss: 0.1161 - val_mse: 0.1161
# Epoch 4/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1057 - mse: 0.1057 - val_loss: 0.1135 - val_mse: 0.1135
# Epoch 5/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1050 - mse: 0.1050 - val_loss: 0.1149 - val_mse: 0.1149
# Epoch 6/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1048 - mse: 0.1048 - val_loss: 0.1135 - val_mse: 0.1135
# Epoch 7/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1042 - mse: 0.1042 - val_loss: 0.1137 - val_mse: 0.1137
# Epoch 8/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1043 - mse: 0.1043 - val_loss: 0.1131 - val_mse: 0.1131
# Epoch 9/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1040 - mse: 0.1040 - val_loss: 0.1143 - val_mse: 0.1143
# Epoch 10/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1037 - mse: 0.1037 - val_loss: 0.1162 - val_mse: 0.1162
# Epoch 11/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1041 - mse: 0.1041 - val_loss: 0.1173 - val_mse: 0.1173
# Epoch 12/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1038 - mse: 0.1038 - val_loss: 0.1129 - val_mse: 0.1129
# Epoch 13/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.1138 - val_mse: 0.1138
# Epoch 14/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1026 - mse: 0.1026 - val_loss: 0.1142 - val_mse: 0.1142
# Epoch 15/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.1134 - val_mse: 0.1134
# Epoch 16/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1025 - mse: 0.1025 - val_loss: 0.1144 - val_mse: 0.1144
# Epoch 17/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1024 - mse: 0.1024 - val_loss: 0.1140 - val_mse: 0.1140
# Epoch 18/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1026 - mse: 0.1026 - val_loss: 0.1133 - val_mse: 0.1133
# Epoch 19/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1022 - mse: 0.1022 - val_loss: 0.1124 - val_mse: 0.1124
# Epoch 20/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1016 - mse: 0.1016 - val_loss: 0.1150 - val_mse: 0.1150
# Epoch 21/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1017 - mse: 0.1017 - val_loss: 0.1112 - val_mse: 0.1112
# Epoch 22/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1021 - mse: 0.1021 - val_loss: 0.1143 - val_mse: 0.1143
# Epoch 23/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1018 - mse: 0.1018 - val_loss: 0.1128 - val_mse: 0.1128
# Epoch 24/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1011 - mse: 0.1011 - val_loss: 0.1122 - val_mse: 0.1122
# Epoch 25/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1010 - mse: 0.1010 - val_loss: 0.1127 - val_mse: 0.1127
# Epoch 26/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1008 - mse: 0.1008 - val_loss: 0.1120 - val_mse: 0.1120
# Epoch 27/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1008 - mse: 0.1008 - val_loss: 0.1116 - val_mse: 0.1116
# Epoch 28/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1005 - mse: 0.1005 - val_loss: 0.1138 - val_mse: 0.1138
# Epoch 29/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1008 - mse: 0.1008 - val_loss: 0.1118 - val_mse: 0.1118
# Epoch 30/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1002 - mse: 0.1002 - val_loss: 0.1125 - val_mse: 0.1125
# Epoch 31/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1001 - mse: 0.1001 - val_loss: 0.1122 - val_mse: 0.1122
# Epoch 32/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1005 - mse: 0.1005 - val_loss: 0.1130 - val_mse: 0.1130
# Epoch 33/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1001 - mse: 0.1001 - val_loss: 0.1116 - val_mse: 0.1116
# Epoch 34/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1003 - mse: 0.1003 - val_loss: 0.1119 - val_mse: 0.1119
# Epoch 35/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0995 - mse: 0.0995 - val_loss: 0.1139 - val_mse: 0.1139
# Epoch 36/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0999 - mse: 0.0999 - val_loss: 0.1127 - val_mse: 0.1127
# Epoch 37/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0995 - mse: 0.0995 - val_loss: 0.1121 - val_mse: 0.1121
# Epoch 38/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0998 - mse: 0.0998 - val_loss: 0.1108 - val_mse: 0.1108
# Epoch 39/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0999 - mse: 0.0999 - val_loss: 0.1112 - val_mse: 0.1112
# Epoch 40/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0993 - mse: 0.0993 - val_loss: 0.1118 - val_mse: 0.1118
# Epoch 41/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1119 - val_mse: 0.1119
# Epoch 42/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1150 - val_mse: 0.1150
# Epoch 43/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0993 - mse: 0.0993 - val_loss: 0.1110 - val_mse: 0.1110
# Epoch 44/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0994 - mse: 0.0994 - val_loss: 0.1125 - val_mse: 0.1125
# Epoch 45/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1100 - val_mse: 0.1100
# Epoch 46/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0986 - mse: 0.0986 - val_loss: 0.1126 - val_mse: 0.1126
# Epoch 47/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0985 - mse: 0.0985 - val_loss: 0.1103 - val_mse: 0.1103
# Epoch 48/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0995 - mse: 0.0995 - val_loss: 0.1112 - val_mse: 0.1112
# Epoch 49/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0984 - mse: 0.0984 - val_loss: 0.1098 - val_mse: 0.1098
# Epoch 50/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0982 - mse: 0.0982 - val_loss: 0.1104 - val_mse: 0.1104
# Epoch 51/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0984 - mse: 0.0984 - val_loss: 0.1121 - val_mse: 0.1121
# Epoch 52/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0981 - mse: 0.0981 - val_loss: 0.1098 - val_mse: 0.1098
# Epoch 53/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0985 - mse: 0.0985 - val_loss: 0.1111 - val_mse: 0.1111
# Epoch 54/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0983 - mse: 0.0983 - val_loss: 0.1105 - val_mse: 0.1105
# Epoch 55/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0980 - mse: 0.0980 - val_loss: 0.1098 - val_mse: 0.1098
# Epoch 56/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0977 - mse: 0.0977 - val_loss: 0.1100 - val_mse: 0.1100
# Epoch 57/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0982 - mse: 0.0982 - val_loss: 0.1104 - val_mse: 0.1104
# Epoch 58/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0979 - mse: 0.0979 - val_loss: 0.1091 - val_mse: 0.1091
# Epoch 59/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0979 - mse: 0.0979 - val_loss: 0.1100 - val_mse: 0.1100
# Epoch 60/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0978 - mse: 0.0978 - val_loss: 0.1091 - val_mse: 0.1091
# Epoch 61/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0973 - mse: 0.0973 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 62/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0975 - mse: 0.0975 - val_loss: 0.1093 - val_mse: 0.1093
# Epoch 63/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0973 - mse: 0.0973 - val_loss: 0.1113 - val_mse: 0.1113
# Epoch 64/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0971 - mse: 0.0971 - val_loss: 0.1096 - val_mse: 0.1096
# Epoch 65/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0969 - mse: 0.0969 - val_loss: 0.1098 - val_mse: 0.1098
# Epoch 66/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0972 - mse: 0.0972 - val_loss: 0.1094 - val_mse: 0.1094
# Epoch 67/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0971 - mse: 0.0971 - val_loss: 0.1094 - val_mse: 0.1094
# Epoch 68/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0974 - mse: 0.0974 - val_loss: 0.1078 - val_mse: 0.1078
# Epoch 69/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0963 - mse: 0.0963 - val_loss: 0.1088 - val_mse: 0.1088
# Epoch 70/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0966 - mse: 0.0966 - val_loss: 0.1106 - val_mse: 0.1106
# Epoch 71/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0964 - mse: 0.0964 - val_loss: 0.1100 - val_mse: 0.1100
# Epoch 72/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0965 - mse: 0.0965 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 73/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0965 - mse: 0.0965 - val_loss: 0.1088 - val_mse: 0.1088
# Epoch 74/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0965 - mse: 0.0965 - val_loss: 0.1092 - val_mse: 0.1092
# Epoch 75/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0963 - mse: 0.0963 - val_loss: 0.1085 - val_mse: 0.1085
# Epoch 76/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0969 - mse: 0.0969 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 77/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0960 - mse: 0.0960 - val_loss: 0.1110 - val_mse: 0.1110
# Epoch 78/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0960 - mse: 0.0960 - val_loss: 0.1100 - val_mse: 0.1100
# Epoch 79/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0961 - mse: 0.0961 - val_loss: 0.1111 - val_mse: 0.1111
# Epoch 80/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0965 - mse: 0.0965 - val_loss: 0.1089 - val_mse: 0.1089
# Epoch 81/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0959 - mse: 0.0959 - val_loss: 0.1080 - val_mse: 0.1080
# Epoch 82/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0954 - mse: 0.0954 - val_loss: 0.1075 - val_mse: 0.1075
# Epoch 83/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0958 - mse: 0.0958 - val_loss: 0.1095 - val_mse: 0.1095
# Epoch 84/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0957 - mse: 0.0957 - val_loss: 0.1083 - val_mse: 0.1083
# Epoch 85/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0957 - mse: 0.0957 - val_loss: 0.1076 - val_mse: 0.1076
# Epoch 86/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0958 - mse: 0.0958 - val_loss: 0.1079 - val_mse: 0.1079
# Epoch 87/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0953 - mse: 0.0953 - val_loss: 0.1081 - val_mse: 0.1081
# Epoch 88/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0951 - mse: 0.0951 - val_loss: 0.1096 - val_mse: 0.1096
# Epoch 89/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0957 - mse: 0.0957 - val_loss: 0.1088 - val_mse: 0.1088
# Epoch 90/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0955 - mse: 0.0955 - val_loss: 0.1071 - val_mse: 0.1071
# Epoch 91/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0946 - mse: 0.0946 - val_loss: 0.1079 - val_mse: 0.1079
# Epoch 92/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0948 - mse: 0.0948 - val_loss: 0.1088 - val_mse: 0.1088
# Epoch 93/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0952 - mse: 0.0952 - val_loss: 0.1083 - val_mse: 0.1083
# Epoch 94/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0950 - mse: 0.0950 - val_loss: 0.1089 - val_mse: 0.1089
# Epoch 95/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0954 - mse: 0.0954 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 96/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0943 - mse: 0.0943 - val_loss: 0.1069 - val_mse: 0.1069
# Epoch 97/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0945 - mse: 0.0945 - val_loss: 0.1082 - val_mse: 0.1082
# Epoch 98/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0950 - mse: 0.0950 - val_loss: 0.1071 - val_mse: 0.1071
# Epoch 99/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0947 - mse: 0.0947 - val_loss: 0.1073 - val_mse: 0.1073
# Epoch 100/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0946 - mse: 0.0946 - val_loss: 0.1085 - val_mse: 0.1085

# %%
# Detect anomalies
y_pred = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - y_pred, 2), axis=1)
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
# Define a threshold for anomaly detection
threshold = np.percentile(mse, 95)  # Adjust the percentile as needed

# %%
# Predict anomalies
anomalies = mse > threshold

# %%
# Calculate the number of anomalies
num_anomalies = np.sum(anomalies)
print(f"Number of Anomalies: {num_anomalies}")
# Out:
# Number of Anomalies: 50

# %%
plt.plot(mse, marker='o', linestyle='', markersize=3, label='MSE')
plt.axhline(threshold, color='r', linestyle='--', label='Anomaly Threshold')
plt.xlabel('Sample Index')
plt.ylabel('MSE')
plt.title('Anomaly Detection Results')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(X_test[0], label='Original ECG')
plt.plot(y_pred[0], label='Reconstructed ECG')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.title('Normal ECG')
plt.show()

# %%
# listing the index of anomalies in X_test
anomalies_index = []
for index, anomaly in enumerate(anomalies):
    if anomaly == True :
        anomalies_index.append(index)

# %%
n = 4
anomaly_index = anomalies_index[n]
plt.plot(X_test[anomaly_index], label='Original ECG')
plt.plot(y_pred[anomaly_index], label='Reconstructed ECG')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.title('ECG and Anomalies')
plt.show()
